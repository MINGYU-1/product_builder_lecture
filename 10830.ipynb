# %%
def solve(A,B,n):
    rst = [[0]*n for _ in range(n)]
    for i in range(n):
        for j in range(n):
            for k in range(n):
                rst[i][j] += (A[i][k]*B[k][j])
            rst[i][j] %= 1000
    return rst
def mat():
    matA = []
    n,b =[int(x) for x in map(int,input().split())]
    for _ in range(n):
        tmp = [int(i) for i in map(int,input().split())]
        matA.append(tmp)
    for i in range(n):
        for j in range(n):
            matA[i][j] %= 1000
    rst = [[0]*n for _ in range(n)]
    for i in range(n):
    
            rst[i]
    return matA
print(mat())
# Out:
# [[1, 2, 3], [4, 5, 6], [7, 8, 9]]
